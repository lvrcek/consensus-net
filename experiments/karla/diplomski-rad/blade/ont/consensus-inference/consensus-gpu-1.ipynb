# %%
import numpy as np

import sys

module_path = '/home/diplomski-rad/consensus-net/'
if module_path not in sys.path:
    print('Adding src module.')
    sys.path.append(module_path)
    
import src

module_path = '/home/diplomski-rad/consensus-net/src/python/inference/'
if module_path not in sys.path:
    print('Adding inference module.')
    sys.path.append(module_path)

import inference

module_path = '/home/diplomski-rad/consensus-net/src/python/dataset/'
if module_path not in sys.path:
    print('Adding dataset module.')
    sys.path.append(module_path)

import pileups
# Out:
# Adding src module.
# Adding inference module.
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Adding dataset module.

# %% [markdown]
# ## n15 model-11 trained od s-cerv mix R7&9

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae/model-11.h5'
assembly_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta']
reference_paths = ['/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta']
bam_file_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm-sorted.bam']
neighbourhood_size = 15
output_dirs = ['./s-cerv-r7-288c-n15-model-11',
               './s-cerv-r9-288c-n15-model-11',
               './-e-coli-n15-model-11']
tools_dir = '/home/diplomski-rad/'
include_indels = True

for assembly_path, reference_path, bam_file_path, output_dir in zip(assembly_paths, reference_paths, bam_file_paths, output_dirs):
    inference.make_consensus(
        model_path, 
        assembly_path,
        reference_path,
        bam_file_path,
        neighbourhood_size,
        output_dir,
        tools_dir,
        include_indels=include_indels)
# Out:
# N/A% (0 of 11859996) |                   | Elapsed Time: 0:00:00 ETA:  --:--:--
# ----> Create pileups from assembly. <----
# ##### Generate pileups from read alignments to reference. #####
# -----> 1. Generate pileups. <-----
# 100% (11859996 of 11859996) |############| Elapsed Time: 0:14:16 Time:  0:14:16
# N/A% (0 of 11859996) |                   | Elapsed Time: 0:00:00 ETA:  --:--:--
# -----> 2. Generate ground truth. <-----
# Parsing contig utg000001l, len: 425163
#   3% (460354 of 11859996) |              | Elapsed Time: 0:00:02 ETA:   0:01:03
# Parsing contig utg000002l, len: 804497
#  10% (1255184 of 11859996) |#            | Elapsed Time: 0:00:07 ETA:   0:00:59
# Parsing contig utg000003l, len: 658814
#  16% (1926931 of 11859996) |##           | Elapsed Time: 0:00:10 ETA:   0:00:55
# Parsing contig utg000004l, len: 459353
#  19% (2370605 of 11859996) |##           | Elapsed Time: 0:00:13 ETA:   0:00:52
# Parsing contig utg000005l, len: 1492881
# ...

# %% [markdown]
# ## n20 model-11 trained od s-cerv mix R7&9

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae/model-11.h5'
assembly_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta']
reference_paths = ['/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta']
bam_file_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm-sorted.bam']
neighbourhood_size = 20
output_dirs = ['./s-cerv-r7-288c-n20-model-11',
               './s-cerv-r9-288c-n20-model-11',
               './-e-coli-n20-model-11']
tools_dir = '/home/diplomski-rad/'
include_indels = True

for assembly_path, reference_path, bam_file_path, output_dir in zip(assembly_paths, reference_paths, bam_file_paths, output_dirs):
    inference.make_consensus(
        model_path, 
        assembly_path,
        reference_path,
        bam_file_path,
        neighbourhood_size,
        output_dir,
        tools_dir,
        include_indels=include_indels)
# Out:
# ----> Create pileups from assembly. <----
# ##### Generate pileups from read alignments to reference. #####
# -----> 1. Generate pileups. <-----
# 100% (11859996 of 11859996) |############| Elapsed Time: 0:15:25 Time:  0:15:25
# -----> 2. Generate ground truth. <-----
#   0% (33195 of 11859996) |               | Elapsed Time: 0:00:00 ETA:   0:01:11
# Parsing contig utg000001l, len: 425163
#   3% (447985 of 11859996) |              | Elapsed Time: 0:00:02 ETA:   0:01:08
# Parsing contig utg000002l, len: 804497
#  10% (1262571 of 11859996) |#            | Elapsed Time: 0:00:07 ETA:   0:01:04
# Parsing contig utg000003l, len: 658814
#  16% (1913468 of 11859996) |##           | Elapsed Time: 0:00:11 ETA:   0:01:00
# Parsing contig utg000004l, len: 459353
#  20% (2372921 of 11859996) |##           | Elapsed Time: 0:00:14 ETA:   0:00:57
# Parsing contig utg000005l, len: 1492881
#  32% (3867888 of 11859996) |####         | Elapsed Time: 0:00:23 ETA:   0:00:48
# ...

# %% [markdown]
# ## n20 model-7 trained od s-cerv mix R7&9

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae/model-7.h5'
assembly_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta']
reference_paths = ['/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta']
bam_file_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm-sorted.bam']
neighbourhood_size = 20
output_dirs = ['./s-cerv-r7-288c-n20-model-7',
               './s-cerv-r9-288c-n20-model-7',
               './-e-coli-n20-model-7']
tools_dir = '/home/diplomski-rad/'
include_indels = True

for assembly_path, reference_path, bam_file_path, output_dir in zip(assembly_paths, reference_paths, bam_file_paths, output_dirs):
    inference.make_consensus(
        model_path, 
        assembly_path,
        reference_path,
        bam_file_path,
        neighbourhood_size,
        output_dir,
        tools_dir,
        include_indels=include_indels)
# Out:
# ----> Create pileups from assembly. <----
# ##### Generate pileups from read alignments to reference. #####
# -----> 1. Generate pileups. <-----
# 100% (11859996 of 11859996) |############| Elapsed Time: 0:15:36 Time:  0:15:36
# -----> 2. Generate ground truth. <-----
#   0% (32838 of 11859996) |               | Elapsed Time: 0:00:00 ETA:   0:01:12
# Parsing contig utg000001l, len: 425163
#   3% (450380 of 11859996) |              | Elapsed Time: 0:00:02 ETA:   0:01:08
# Parsing contig utg000002l, len: 804497
#  10% (1252106 of 11859996) |#            | Elapsed Time: 0:00:07 ETA:   0:01:03
# Parsing contig utg000003l, len: 658814
#  16% (1914916 of 11859996) |##           | Elapsed Time: 0:00:11 ETA:   0:00:59
# Parsing contig utg000004l, len: 459353
#  20% (2381645 of 11859996) |##           | Elapsed Time: 0:00:14 ETA:   0:00:57
# Parsing contig utg000005l, len: 1492881
#  32% (3866061 of 11859996) |####         | Elapsed Time: 0:00:23 ETA:   0:00:48
# ...

# %% [markdown]
# ## n15 model-7 trained od s-cerv mix R7&9

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae/model-7.h5'
assembly_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta']
reference_paths = ['/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta']
bam_file_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm-sorted.bam']
neighbourhood_size = 15
output_dirs = ['./s-cerv-r7-288c-n15-model-7',
               './s-cerv-r9-288c-n15-model-7',
               './-e-coli-n15-model-7']
tools_dir = '/home/diplomski-rad/'
include_indels = True

for assembly_path, reference_path, bam_file_path, output_dir in zip(assembly_paths, reference_paths, bam_file_paths, output_dirs):
    inference.make_consensus(
        model_path, 
        assembly_path,
        reference_path,
        bam_file_path,
        neighbourhood_size,
        output_dir,
        tools_dir,
        include_indels=include_indels)
# Out:
# ----> Create pileups from assembly. <----
# ##### Generate pileups from read alignments to reference. #####
# -----> 1. Generate pileups. <-----
# 100% (11859996 of 11859996) |############| Elapsed Time: 0:15:42 Time:  0:15:42
# -----> 2. Generate ground truth. <-----
#   0% (32317 of 11859996) |               | Elapsed Time: 0:00:00 ETA:   0:01:13
# Parsing contig utg000001l, len: 425163
#   3% (446704 of 11859996) |              | Elapsed Time: 0:00:02 ETA:   0:01:09
# Parsing contig utg000002l, len: 804497
#  10% (1257577 of 11859996) |#            | Elapsed Time: 0:00:07 ETA:   0:01:03
# Parsing contig utg000003l, len: 658814
#  16% (1914168 of 11859996) |##           | Elapsed Time: 0:00:11 ETA:   0:01:00
# Parsing contig utg000004l, len: 459353
#  20% (2373068 of 11859996) |##           | Elapsed Time: 0:00:14 ETA:   0:00:57
# Parsing contig utg000005l, len: 1492881
#  32% (3876078 of 11859996) |####         | Elapsed Time: 0:00:23 ETA:   0:00:49
# ...

# %% [markdown]
# ## n15 model-13 trained od s-cerv mix R7&9

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae/model-13.h5'
assembly_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta']
reference_paths = ['/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta']
bam_file_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm-sorted.bam']
neighbourhood_size = 15
output_dirs = ['./s-cerv-r7-288c-n15-model-13',
               './s-cerv-r9-288c-n15-model-13',
               './-e-coli-n15-model-13']
tools_dir = '/home/diplomski-rad/'
include_indels = True

for assembly_path, reference_path, bam_file_path, output_dir in zip(assembly_paths, reference_paths, bam_file_paths, output_dirs):
    inference.make_consensus(
        model_path, 
        assembly_path,
        reference_path,
        bam_file_path,
        neighbourhood_size,
        output_dir,
        tools_dir,
        include_indels=include_indels)
# Out:
#   0% (1126 of 11859996) |                | Elapsed Time: 0:00:00 ETA:   0:17:34
# ----> Create pileups from assembly. <----
# ##### Generate pileups from read alignments to reference. #####
# -----> 1. Generate pileups. <-----
# 100% (11859996 of 11859996) |############| Elapsed Time: 0:13:56 Time:  0:13:56
#   0% (17674 of 11859996) |               | Elapsed Time: 0:00:00 ETA:   0:01:07
# -----> 2. Generate ground truth. <-----
# Parsing contig utg000001l, len: 425163
#   3% (447035 of 11859996) |              | Elapsed Time: 0:00:02 ETA:   0:01:06
# Parsing contig utg000002l, len: 804497
#  10% (1254826 of 11859996) |#            | Elapsed Time: 0:00:07 ETA:   0:00:57
# Parsing contig utg000003l, len: 658814
#  16% (1924542 of 11859996) |##           | Elapsed Time: 0:00:10 ETA:   0:00:54
# Parsing contig utg000004l, len: 459353
#  20% (2374267 of 11859996) |##           | Elapsed Time: 0:00:13 ETA:   0:00:51
# Parsing contig utg000005l, len: 1492881
# ...

# %% [markdown]
# ## n15 model-2 trained od s-cerv mix R7&9

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae/model-2.h5'
assembly_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta']
reference_paths = ['/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta']
bam_file_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm-sorted.bam']
neighbourhood_size = 15
output_dirs = ['./s-cerv-r7-288c-n15-model-2',
               './s-cerv-r9-288c-n15-model-2',
               './-e-coli-n15-model-2']
tools_dir = '/home/diplomski-rad/'
include_indels = True

for assembly_path, reference_path, bam_file_path, output_dir in zip(assembly_paths, reference_paths, bam_file_paths, output_dirs):
    inference.make_consensus(
        model_path, 
        assembly_path,
        reference_path,
        bam_file_path,
        neighbourhood_size,
        output_dir,
        tools_dir,
        include_indels=include_indels)
# Out:
# ----> Create pileups from assembly. <----
# ##### Generate pileups from read alignments to reference. #####
# -----> 1. Generate pileups. <-----
# 100% (11859996 of 11859996) |############| Elapsed Time: 0:15:06 Time:  0:15:06
# -----> 2. Generate ground truth. <-----
#   0% (34739 of 11859996) |               | Elapsed Time: 0:00:00 ETA:   0:01:08
# Parsing contig utg000001l, len: 425163
#   3% (446195 of 11859996) |              | Elapsed Time: 0:00:02 ETA:   0:01:06
# Parsing contig utg000002l, len: 804497
#  10% (1253005 of 11859996) |#            | Elapsed Time: 0:00:07 ETA:   0:01:00
# Parsing contig utg000003l, len: 658814
#  16% (1923976 of 11859996) |##           | Elapsed Time: 0:00:11 ETA:   0:00:57
# Parsing contig utg000004l, len: 459353
#  20% (2375108 of 11859996) |##           | Elapsed Time: 0:00:13 ETA:   0:00:54
# Parsing contig utg000005l, len: 1492881
#  32% (3874376 of 11859996) |####         | Elapsed Time: 0:00:22 ETA:   0:00:45
# ...

# %% [markdown]
# ## n20 model-2 trained od s-cerv mix R7&9

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae/model-2.h5'
assembly_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta']
reference_paths = ['/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta']
bam_file_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm-sorted.bam']
neighbourhood_size = 20
output_dirs = ['./s-cerv-r7-288c-n20-model-2',
               './s-cerv-r9-288c-n20-model-2',
               './-e-coli-n20-model-2']
tools_dir = '/home/diplomski-rad/'
include_indels = True

for assembly_path, reference_path, bam_file_path, output_dir in zip(assembly_paths, reference_paths, bam_file_paths, output_dirs):
    inference.make_consensus(
        model_path, 
        assembly_path,
        reference_path,
        bam_file_path,
        neighbourhood_size,
        output_dir,
        tools_dir,
        include_indels=include_indels)
# Out:
# ----> Create pileups from assembly. <----
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-6ab970baf46f> in <module>()
#      25         output_dir,
#      26         tools_dir,
# ---> 27         include_indels=include_indels)
#
# /home/diplomski-rad/consensus-net/src/python/inference/inference.py in make_consensus(model_path, assembly_fasta_path, reference_path, bam_file_path, neighbourhood_size, output_dir, tools_dir, include_indels)
#      36         mode='inference',
#      37         save_directory_path=output_dir,
# ---> 38         include_indels=include_indels)
#      39
#      40     print('----> Create dataset with neighbourhood from pileups. <----')
#
# /home/diplomski-rad/consensus-net/src/python/dataset/dataset.py in generate_pileups(bam_file_path, reference_fasta_path, mode, save_directory_path, include_indels)
# ...

# %% [markdown]
# ## n20 model-12 trained od s-cerv mix R7&9

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae/model-12.h5'
assembly_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta']
reference_paths = ['/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta']
bam_file_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm-sorted.bam']
neighbourhood_size = 20
output_dirs = ['./s-cerv-r7-288c-n20-model-12',
               './s-cerv-r9-288c-n20-model-12',
               './-e-coli-n20-model-12']
tools_dir = '/home/diplomski-rad/'
include_indels = True

for assembly_path, reference_path, bam_file_path, output_dir in zip(assembly_paths, reference_paths, bam_file_paths, output_dirs):
    inference.make_consensus(
        model_path, 
        assembly_path,
        reference_path,
        bam_file_path,
        neighbourhood_size,
        output_dir,
        tools_dir,
        include_indels=include_indels)

# %% [markdown]
# ## n15 model-11 trained od s-cerv mix R7&9 indel-classes

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-indel-classes/model-11.h5'
assembly_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta']
reference_paths = ['/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta']
bam_file_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm-sorted.bam']
neighbourhood_size = 15
output_dirs = ['./s-cerv-r7-288c-n15-model-11-indel-classes',
               './s-cerv-r9-288c-n15-model-11-indel-classes',
               './-e-coli-n15-model-11-indel-classes']
tools_dir = '/home/diplomski-rad/'
include_indels = True

for assembly_path, reference_path, bam_file_path, output_dir in zip(assembly_paths, reference_paths, bam_file_paths, output_dirs):
    inference.make_consensus(
        model_path, 
        assembly_path,
        reference_path,
        bam_file_path,
        neighbourhood_size,
        output_dir,
        tools_dir,
        include_indels=include_indels)
# Out:
#   0% (946 of 11859996) |                 | Elapsed Time: 0:00:00 ETA:   0:20:54
# ----> Create pileups from assembly. <----
# ##### Generate pileups from read alignments to reference. #####
# 100% (11859996 of 11859996) |############| Elapsed Time: 0:16:39 Time:  0:16:39
# ----> Create dataset with neighbourhood from pileups. <----
# Parsing  ./s-cerv-r7-288c-n15-model-11-indel-classes/pileups-X-0-indels.npy  and  ./s-cerv-r7-288c-n15-model-11-indel-classes/pileups-y-0.npy
#   0% (3901 of 425163) |                  | Elapsed Time: 0:00:00 ETA:   0:00:21
# Creating dataset with neighbourhood ...
# 100% (425163 of 425163) |################| Elapsed Time: 0:00:21 Time:  0:00:21
# Parsing  ./s-cerv-r7-288c-n15-model-11-indel-classes/pileups-X-1-indels.npy  and  ./s-cerv-r7-288c-n15-model-11-indel-classes/pileups-y-1.npy
#   0% (4133 of 804497) |                  | Elapsed Time: 0:00:00 ETA:   0:00:38
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n15 model-7 trained od s-cerv mix R7&9 indel-classes

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-indel-classes/model-7.h5'
assembly_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta']
reference_paths = ['/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta']
bam_file_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm-sorted.bam']
neighbourhood_size = 15
output_dirs = ['./s-cerv-r7-288c-n15-model-7-indel-classes',
               './s-cerv-r9-288c-n15-model-7-indel-classes',
               './-e-coli-n15-model-7-indel-classes']
tools_dir = '/home/diplomski-rad/'
include_indels = True

for assembly_path, reference_path, bam_file_path, output_dir in zip(assembly_paths, reference_paths, bam_file_paths, output_dirs):
    inference.make_consensus(
        model_path, 
        assembly_path,
        reference_path,
        bam_file_path,
        neighbourhood_size,
        output_dir,
        tools_dir,
        include_indels=include_indels)
# Out:
# ----> Create pileups from assembly. <----
# ##### Generate pileups from read alignments to reference. #####
# 100% (11859996 of 11859996) |############| Elapsed Time: 0:17:32 Time:  0:17:32
# ----> Create dataset with neighbourhood from pileups. <----
# Parsing  ./s-cerv-r7-288c-n15-model-7-indel-classes/pileups-X-0-indels.npy  and  ./s-cerv-r7-288c-n15-model-7-indel-classes/pileups-y-0.npy
#   0% (3866 of 425163) |                  | Elapsed Time: 0:00:00 ETA:   0:00:21
# Creating dataset with neighbourhood ...
# 100% (425163 of 425163) |################| Elapsed Time: 0:00:21 Time:  0:00:21
# Parsing  ./s-cerv-r7-288c-n15-model-7-indel-classes/pileups-X-1-indels.npy  and  ./s-cerv-r7-288c-n15-model-7-indel-classes/pileups-y-1.npy
#   0% (3920 of 804497) |                  | Elapsed Time: 0:00:00 ETA:   0:00:40
# Creating dataset with neighbourhood ...
# 100% (804497 of 804497) |################| Elapsed Time: 0:00:41 Time:  0:00:41
# ...

# %% [markdown]
# ## n20 model-11 trained od s-cerv mix R7&9 indel-classes

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae-indel-classes/model-11.h5'
assembly_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
#                   '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
#                   '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
                 ]
reference_paths = ['/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
#                    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
#                    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
                  ]
bam_file_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm-sorted.bam',
#                   '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm-sorted.bam',
#                   '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm-sorted.bam'
                 ]
neighbourhood_size = 20
output_dirs = ['./s-cerv-r7-288c-n20-model-11-indel-classes',
#                './s-cerv-r9-288c-n20-model-11-indel-classes',
#                './-e-coli-n20-model-11-indel-classes'
              ]
tools_dir = '/home/diplomski-rad/'
include_indels = True

for assembly_path, reference_path, bam_file_path, output_dir in zip(assembly_paths, reference_paths, bam_file_paths, output_dirs):
    inference.make_consensus(
        model_path, 
        assembly_path,
        reference_path,
        bam_file_path,
        neighbourhood_size,
        output_dir,
        tools_dir,
        include_indels=include_indels)
# Out:
# ----> Create pileups from assembly. <----
# ##### Generate pileups from read alignments to reference. #####
# 100% (11859996 of 11859996) |############| Elapsed Time: 0:18:24 Time:  0:18:24
# ----> Create dataset with neighbourhood from pileups. <----
# Parsing  ./s-cerv-r7-288c-n20-model-11-indel-classes/pileups-X-0-indels.npy  and  ./s-cerv-r7-288c-n20-model-11-indel-classes/pileups-y-0.npy
#   0% (3063 of 425163) |                  | Elapsed Time: 0:00:00 ETA:   0:00:27
# Creating dataset with neighbourhood ...
# 100% (425163 of 425163) |################| Elapsed Time: 0:00:27 Time:  0:00:27
# Parsing  ./s-cerv-r7-288c-n20-model-11-indel-classes/pileups-X-1-indels.npy  and  ./s-cerv-r7-288c-n20-model-11-indel-classes/pileups-y-1.npy
#   0% (3000 of 804497) |                  | Elapsed Time: 0:00:00 ETA:   0:00:53
# Creating dataset with neighbourhood ...
# 100% (804497 of 804497) |################| Elapsed Time: 0:00:48 Time:  0:00:48
# ...

# %% [markdown]
# ## n20 model-7 trained od s-cerv mix R7&9 indel-classes

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae-indel-classes/model-7.h5'
assembly_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta']
reference_paths = ['/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
                   '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta']
bam_file_paths = ['/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm-sorted.bam',
                  '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm-sorted.bam']
neighbourhood_size = 20
output_dirs = ['./s-cerv-r7-288c-n20-model-7-indel-classes',
               './s-cerv-r9-288c-n20-model-7-indel-classes',
               './-e-coli-n20-model-7-indel-classes']
tools_dir = '/home/diplomski-rad/'
include_indels = True

for assembly_path, reference_path, bam_file_path, output_dir in zip(assembly_paths, reference_paths, bam_file_paths, output_dirs):
    inference.make_consensus(
        model_path, 
        assembly_path,
        reference_path,
        bam_file_path,
        neighbourhood_size,
        output_dir,
        tools_dir,
        include_indels=include_indels)
# Out:
# ----> Create pileups from assembly. <----
# ##### Generate pileups from read alignments to reference. #####
# 100% (11859996 of 11859996) |############| Elapsed Time: 0:17:46 Time:  0:17:46
# ----> Create dataset with neighbourhood from pileups. <----
# Parsing  ./s-cerv-r7-288c-n20-model-7-indel-classes/pileups-X-0-indels.npy  and  ./s-cerv-r7-288c-n20-model-7-indel-classes/pileups-y-0.npy
#   0% (3749 of 425163) |                  | Elapsed Time: 0:00:00 ETA:   0:00:22
# Creating dataset with neighbourhood ...
# 100% (425163 of 425163) |################| Elapsed Time: 0:00:22 Time:  0:00:22
# Parsing  ./s-cerv-r7-288c-n20-model-7-indel-classes/pileups-X-1-indels.npy  and  ./s-cerv-r7-288c-n20-model-7-indel-classes/pileups-y-1.npy
#   0% (3781 of 804497) |                  | Elapsed Time: 0:00:00 ETA:   0:00:42
# Creating dataset with neighbourhood ...
# 100% (804497 of 804497) |################| Elapsed Time: 0:00:43 Time:  0:00:43
# ...

# %% [markdown]
# ## n20 model-11 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae-racon-hax/model-11.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 20
output_dirs = [
    './s-cerv-r7-288c-n20-model-11-racon-hax',
    './s-cerv-r9-288c-n20-model-11-racon-hax',
    './-e-coli-n20-model-11-racon-hax'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:07:25 Time:  0:07:25
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3865 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:16:31
# Creating dataset with neighbourhood ...
#   3% (695730 of 19138428) |              | Elapsed Time: 0:00:37 ETA:   2:54:18
# Creating dataset with neighbourhood ...
#  10% (1994357 of 19138428) |#            | Elapsed Time: 0:01:48 ETA:   3:44:21
# Creating dataset with neighbourhood ...
#  15% (3054899 of 19138428) |##           | Elapsed Time: 0:02:46 ETA:   3:15:25
# Creating dataset with neighbourhood ...
#  19% (3794673 of 19138428) |##           | Elapsed Time: 0:03:27 ETA:   2:29:49
# Creating dataset with neighbourhood ...
#  32% (6196144 of 19138428) |####         | Elapsed Time: 0:05:38 ETA:   4:24:55
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n20 model-7 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae-racon-hax/model-7.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 20
output_dirs = [
    './s-cerv-r7-288c-n20-model-7-racon-hax',
    './s-cerv-r9-288c-n20-model-7-racon-hax',
    './-e-coli-n20-model-7-racon-hax'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:07:56 Time:  0:07:56
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3596 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:17:45
# Creating dataset with neighbourhood ...
#   3% (695407 of 19138428) |              | Elapsed Time: 0:00:41 ETA:   3:11:19
# Creating dataset with neighbourhood ...
#  10% (1994173 of 19138428) |#            | Elapsed Time: 0:01:58 ETA:   5:13:57
# Creating dataset with neighbourhood ...
#  15% (3054644 of 19138428) |##           | Elapsed Time: 0:03:00 ETA:   3:23:54
# Creating dataset with neighbourhood ...
#  19% (3794287 of 19138428) |##           | Elapsed Time: 0:03:45 ETA:   4:29:15
# Creating dataset with neighbourhood ...
#  32% (6195719 of 19138428) |####         | Elapsed Time: 0:06:07 ETA:   7:18:46
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n15 model-11 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-racon-hax/model-11.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 15
output_dirs = [
    './s-cerv-r7-288c-n15-model-11-racon-hax',
    './s-cerv-r9-288c-n15-model-11-racon-hax',
    './-e-coli-n15-model-11-racon-hax'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:07:31 Time:  0:07:31
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (4081 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:15:38
# Creating dataset with neighbourhood ...
#   3% (695881 of 19138428) |              | Elapsed Time: 0:00:37 ETA:   2:07:54
# Creating dataset with neighbourhood ...
#  10% (1994436 of 19138428) |#            | Elapsed Time: 0:01:46 ETA:   3:37:12
# Creating dataset with neighbourhood ...
#  15% (3054805 of 19138428) |##           | Elapsed Time: 0:02:44 ETA:   2:47:12
# Creating dataset with neighbourhood ...
#  19% (3794514 of 19138428) |##           | Elapsed Time: 0:03:24 ETA:   2:56:08
# Creating dataset with neighbourhood ...
#  32% (6196132 of 19138428) |####         | Elapsed Time: 0:05:32 ETA:   4:15:28
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n15 model-7 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-racon-hax/model-7.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 15
output_dirs = [
    './s-cerv-r7-288c-n15-model-7-racon-hax',
    './s-cerv-r9-288c-n15-model-7-racon-hax',
    './-e-coli-n15-model-7-racon-hax'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:08:05 Time:  0:08:05
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3675 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:17:22
# Creating dataset with neighbourhood ...
#   3% (695425 of 19138428) |              | Elapsed Time: 0:00:40 ETA:   3:05:01
# Creating dataset with neighbourhood ...
#  10% (1994274 of 19138428) |#            | Elapsed Time: 0:01:54 ETA:   4:03:44
# Creating dataset with neighbourhood ...
#  15% (3052825 of 19138428) |##           | Elapsed Time: 0:02:54 ETA:   4:59:02
# Creating dataset with neighbourhood ...
#  19% (3794491 of 19138428) |##           | Elapsed Time: 0:03:37 ETA:   4:06:55
# Creating dataset with neighbourhood ...
#  32% (6195776 of 19138428) |####         | Elapsed Time: 0:05:54 ETA:   5:24:46
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n15 model-15 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-racon-hax/model-15.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 15
output_dirs = [
    './s-cerv-r7-288c-n15-model-15-racon-hax',
    './s-cerv-r9-288c-n15-model-15-racon-hax',
    './e-coli-n15-model-15-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n15-model-15-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n15-model-15-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n15-model-15-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:08:11 Time:  0:08:11
#   0% (24473 of 19138428) |               | Elapsed Time: 0:00:01 ETA:   0:16:57
# ----> Create dataset with neighbourhood from pileups. <----
# Creating dataset with neighbourhood ...
#   3% (695636 of 19138428) |              | Elapsed Time: 0:00:39 ETA:   2:11:58
# Creating dataset with neighbourhood ...
#  10% (1994313 of 19138428) |#            | Elapsed Time: 0:01:52 ETA:   4:04:58
# Creating dataset with neighbourhood ...
#  15% (3054790 of 19138428) |##           | Elapsed Time: 0:02:51 ETA:   3:21:17
# Creating dataset with neighbourhood ...
#  19% (3794652 of 19138428) |##           | Elapsed Time: 0:03:33 ETA:   2:15:08
# Creating dataset with neighbourhood ...
#  32% (6196141 of 19138428) |####         | Elapsed Time: 0:05:46 ETA:   4:04:57
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n15 model-16 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-racon-hax/model-16.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 15
output_dirs = [
    './s-cerv-r7-288c-n15-model-16-racon-hax',
    './s-cerv-r9-288c-n15-model-16-racon-hax',
    './e-coli-n15-model-16-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n15-model-16-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n15-model-16-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n15-model-16-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:07:54 Time:  0:07:54
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3664 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:17:25
# Creating dataset with neighbourhood ...
#   3% (695381 of 19138428) |              | Elapsed Time: 0:00:40 ETA:   2:47:10
# Creating dataset with neighbourhood ...
#  10% (1994131 of 19138428) |#            | Elapsed Time: 0:01:54 ETA:   5:03:49
# Creating dataset with neighbourhood ...
#  15% (3054626 of 19138428) |##           | Elapsed Time: 0:02:55 ETA:   3:27:16
# Creating dataset with neighbourhood ...
#  19% (3794299 of 19138428) |##           | Elapsed Time: 0:03:39 ETA:   3:29:44
# Creating dataset with neighbourhood ...
#  32% (6195774 of 19138428) |####         | Elapsed Time: 0:05:56 ETA:   5:35:25
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n20 model-16 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae-racon-hax/model-16.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 20
output_dirs = [
    './s-cerv-r7-288c-n20-model-16-racon-hax',
    './s-cerv-r9-288c-n20-model-16-racon-hax',
    './e-coli-n20-model-16-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n20-model-16-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n20-model-16-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n20-model-16-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:10:31 Time:  0:10:31
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3353 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:19:05
# Creating dataset with neighbourhood ...
#   3% (695232 of 19138428) |              | Elapsed Time: 0:00:46 ETA:   3:28:06
# Creating dataset with neighbourhood ...
#  10% (1993763 of 19138428) |#            | Elapsed Time: 0:02:11 ETA:   6:02:50
# Creating dataset with neighbourhood ...
#  15% (3054035 of 19138428) |##           | Elapsed Time: 0:03:19 ETA:   5:02:21
# Creating dataset with neighbourhood ...
#  19% (3794231 of 19138428) |##           | Elapsed Time: 0:04:08 ETA:   3:25:03
# Creating dataset with neighbourhood ...
#  32% (6195691 of 19138428) |####         | Elapsed Time: 0:06:40 ETA:   6:23:10
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n20 model-15 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae-racon-hax/model-15.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 20
output_dirs = [
    './s-cerv-r7-288c-n20-model-15-racon-hax',
    './s-cerv-r9-288c-n20-model-15-racon-hax',
    './e-coli-n20-model-15-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n20-model-15-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n20-model-15-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n20-model-15-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:08:45 Time:  0:08:45
#   0% (15467 of 19138428) |               | Elapsed Time: 0:00:00 ETA:   0:18:35
# ----> Create dataset with neighbourhood from pileups. <----
# Creating dataset with neighbourhood ...
#   3% (695301 of 19138428) |              | Elapsed Time: 0:00:42 ETA:   3:16:19
# Creating dataset with neighbourhood ...
#  10% (1994011 of 19138428) |#            | Elapsed Time: 0:02:01 ETA:   4:50:34
# Creating dataset with neighbourhood ...
#  15% (3054418 of 19138428) |##           | Elapsed Time: 0:03:06 ETA:   3:58:31
# Creating dataset with neighbourhood ...
#  19% (3794262 of 19138428) |##           | Elapsed Time: 0:03:52 ETA:   3:37:04
# Creating dataset with neighbourhood ...
#  32% (6195728 of 19138428) |####         | Elapsed Time: 0:06:20 ETA:   6:21:01
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n20 model-19 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae-racon-hax/model-19.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 20
output_dirs = [
    './s-cerv-r7-288c-n20-model-19-racon-hax',
    './s-cerv-r9-288c-n20-model-19-racon-hax',
    './e-coli-n20-model-19-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n20-model-19-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n20-model-19-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n20-model-19-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:07:58 Time:  0:07:58
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3847 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:16:37
# Creating dataset with neighbourhood ...
#   3% (695470 of 19138428) |              | Elapsed Time: 0:00:39 ETA:   2:35:56
# Creating dataset with neighbourhood ...
#  10% (1994283 of 19138428) |#            | Elapsed Time: 0:01:52 ETA:   4:14:36
# Creating dataset with neighbourhood ...
#  15% (3054852 of 19138428) |##           | Elapsed Time: 0:02:52 ETA:   3:45:53
# Creating dataset with neighbourhood ...
#  19% (3794565 of 19138428) |##           | Elapsed Time: 0:03:34 ETA:   2:50:39
# Creating dataset with neighbourhood ...
#  32% (6195992 of 19138428) |####         | Elapsed Time: 0:05:50 ETA:   4:41:20
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n20 model-20 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae-racon-hax/model-20.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 20
output_dirs = [
    './s-cerv-r7-288c-n20-model-20-racon-hax',
    './s-cerv-r9-288c-n20-model-20-racon-hax',
    './e-coli-n20-model-20-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n20-model-20-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n20-model-20-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n20-model-20-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:08:14 Time:  0:08:14
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3769 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:16:56
# Creating dataset with neighbourhood ...
#   3% (695589 of 19138428) |              | Elapsed Time: 0:00:40 ETA:   4:09:04
# Creating dataset with neighbourhood ...
#  10% (1994213 of 19138428) |#            | Elapsed Time: 0:01:54 ETA:   4:37:58
# Creating dataset with neighbourhood ...
#  15% (3054740 of 19138428) |##           | Elapsed Time: 0:02:54 ETA:   4:06:16
# Creating dataset with neighbourhood ...
#  19% (3794381 of 19138428) |##           | Elapsed Time: 0:03:37 ETA:   3:38:42
# Creating dataset with neighbourhood ...
#  32% (6195995 of 19138428) |####         | Elapsed Time: 0:05:53 ETA:   7:07:47
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n15 model-20 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-racon-hax/model-20.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 15
output_dirs = [
    './s-cerv-r7-288c-n15-model-20-racon-hax',
    './s-cerv-r9-288c-n15-model-20-racon-hax',
    './e-coli-n15-model-20-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n15-model-20-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n15-model-20-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n15-model-20-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:08:21 Time:  0:08:21
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3503 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:18:14
# Creating dataset with neighbourhood ...
#   3% (695547 of 19138428) |              | Elapsed Time: 0:00:39 ETA:   3:44:35
# Creating dataset with neighbourhood ...
#  10% (1994261 of 19138428) |#            | Elapsed Time: 0:01:53 ETA:   5:17:19
# Creating dataset with neighbourhood ...
#  15% (3054720 of 19138428) |##           | Elapsed Time: 0:02:53 ETA:   3:38:13
# Creating dataset with neighbourhood ...
#  19% (3794493 of 19138428) |##           | Elapsed Time: 0:03:36 ETA:   3:33:06
# Creating dataset with neighbourhood ...
#  32% (6195980 of 19138428) |####         | Elapsed Time: 0:05:51 ETA:   6:48:22
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n15 model-19 trained od s-cerv mix R7&9 racon-hax

# %%
## Message in output is wrong - new message was not saved. Code was executed successfully.

model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-racon-hax/model-19.h5'
reads_paths = [
#     '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
#     '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
#     '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
#     '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
#     '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
#     '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 15
output_dirs = [
#     './s-cerv-r7-288c-n15-model-19-racon-hax',
#     './s-cerv-r9-288c-n15-model-19-racon-hax',
    './e-coli-n15-model-19-racon-hax'
]
result_file_paths = [
#     '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n15-model-19-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n15-model-19-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n15-model-19-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-9-b20331984fb4> in <module>()
#      54         output_dir,
#      55         tools_dir,
# ---> 56         result_file_path)
#
# /home/diplomski-rad/consensus-net/src/python/inference/inference.py in make_consensus(model_path, reference_path, pileup_generator, neighbourhood_size, output_dir, tools_dir, result_file_path)
#      62
#      63     if os.path.exists(output_dir):
# ---> 64         raise FileExistsError('Given directory already exists: {}! Provide '
#      65                               'non-existing directory.')
#      66
#
# FileExistsError: Given directory already exists: {}! Provide non-existing directory.

# %% [markdown]
# ## n15 model-21 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-racon-hax/model-21.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 15
output_dirs = [
    './s-cerv-r7-288c-n15-model-21-racon-hax',
    './s-cerv-r9-288c-n15-model-21-racon-hax',
    './e-coli-n15-model-21-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n15-model-21-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n15-model-21-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n15-model-21-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:08:00 Time:  0:08:00
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3960 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:16:07
# Creating dataset with neighbourhood ...
#   3% (695741 of 19138428) |              | Elapsed Time: 0:00:36 ETA:   2:23:48
# Creating dataset with neighbourhood ...
#  10% (1994527 of 19138428) |#            | Elapsed Time: 0:01:44 ETA:   3:08:40
# Creating dataset with neighbourhood ...
#  15% (3055047 of 19138428) |##           | Elapsed Time: 0:02:40 ETA:   3:02:44
# Creating dataset with neighbourhood ...
#  19% (3794866 of 19138428) |##           | Elapsed Time: 0:03:19 ETA:   3:11:34
# Creating dataset with neighbourhood ...
#  32% (6196318 of 19138428) |####         | Elapsed Time: 0:05:24 ETA:   3:34:12
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n15 model-22 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-racon-hax/model-22.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 15
output_dirs = [
    './s-cerv-r7-288c-n15-model-22-racon-hax',
    './s-cerv-r9-288c-n15-model-22-racon-hax',
    './e-coli-n15-model-22-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n15-model-22-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n15-model-22-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n15-model-22-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:08:05 Time:  0:08:05
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3868 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:16:30
# Creating dataset with neighbourhood ...
#   3% (695657 of 19138428) |              | Elapsed Time: 0:00:38 ETA:   3:02:56
# Creating dataset with neighbourhood ...
#  10% (1994383 of 19138428) |#            | Elapsed Time: 0:01:50 ETA:   4:24:46
# Creating dataset with neighbourhood ...
#  15% (3054822 of 19138428) |##           | Elapsed Time: 0:02:48 ETA:   3:28:43
# Creating dataset with neighbourhood ...
#  19% (3794569 of 19138428) |##           | Elapsed Time: 0:03:30 ETA:   2:42:45
# Creating dataset with neighbourhood ...
#  32% (6195974 of 19138428) |####         | Elapsed Time: 0:05:42 ETA:   4:08:14
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n20 model-22 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae-racon-hax/model-22.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 20
output_dirs = [
    './s-cerv-r7-288c-n20-model-22-racon-hax',
    './s-cerv-r9-288c-n20-model-22-racon-hax',
    './e-coli-n20-model-22-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n20-model-22-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n20-model-22-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n20-model-22-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:08:06 Time:  0:08:06
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3788 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:16:51
# Creating dataset with neighbourhood ...
#   3% (695573 of 19138428) |              | Elapsed Time: 0:00:39 ETA:   3:36:02
# Creating dataset with neighbourhood ...
#  10% (1994309 of 19138428) |#            | Elapsed Time: 0:01:52 ETA:   3:53:14
# Creating dataset with neighbourhood ...
#  15% (3054811 of 19138428) |##           | Elapsed Time: 0:02:52 ETA:   3:38:47
# Creating dataset with neighbourhood ...
#  19% (3794585 of 19138428) |##           | Elapsed Time: 0:03:34 ETA:   2:51:50
# Creating dataset with neighbourhood ...
#  32% (6195906 of 19138428) |####         | Elapsed Time: 0:05:49 ETA:   4:53:44
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n20 model-21 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae-racon-hax/model-21.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 20
output_dirs = [
    './s-cerv-r7-288c-n20-model-21-racon-hax',
    './s-cerv-r9-288c-n20-model-21-racon-hax',
    './e-coli-n20-model-21-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n20-model-21-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n20-model-21-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n20-model-21-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:07:56 Time:  0:07:56
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3768 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:16:56
# Creating dataset with neighbourhood ...
#   3% (695561 of 19138428) |              | Elapsed Time: 0:00:39 ETA:   3:07:00
# Creating dataset with neighbourhood ...
#  10% (1994262 of 19138428) |#            | Elapsed Time: 0:01:52 ETA:   4:21:42
# Creating dataset with neighbourhood ...
#  15% (3054755 of 19138428) |##           | Elapsed Time: 0:02:52 ETA:   3:14:56
# Creating dataset with neighbourhood ...
#  19% (3794493 of 19138428) |##           | Elapsed Time: 0:03:35 ETA:   3:00:42
# Creating dataset with neighbourhood ...
#  32% (6195990 of 19138428) |####         | Elapsed Time: 0:05:50 ETA:   5:37:59
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n15 model-11-TB trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-racon-hax/model-11-TB.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 15
output_dirs = [
    './s-cerv-r7-288c-n15-model-11-TB-racon-hax',
    './s-cerv-r9-288c-n15-model-11-TB-racon-hax',
    './e-coli-n15-model-11-TB-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n15-model-11-TB-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n15-model-11-TB-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n15-model-11-TB-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:07:40 Time:  0:07:40
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (4102 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:15:33
# Creating dataset with neighbourhood ...
#   3% (695819 of 19138428) |              | Elapsed Time: 0:00:37 ETA:   2:28:35
# Creating dataset with neighbourhood ...
#  10% (1994510 of 19138428) |#            | Elapsed Time: 0:01:45 ETA:   3:35:05
# Creating dataset with neighbourhood ...
#  15% (3054957 of 19138428) |##           | Elapsed Time: 0:02:41 ETA:   2:16:31
# Creating dataset with neighbourhood ...
#  19% (3794738 of 19138428) |##           | Elapsed Time: 0:03:20 ETA:   2:30:15
# Creating dataset with neighbourhood ...
#  32% (6196254 of 19138428) |####         | Elapsed Time: 0:05:27 ETA:   4:37:08
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n15 model-23 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-racon-hax/model-23.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 15
output_dirs = [
    './s-cerv-r7-288c-n15-model-23-racon-hax',
    './s-cerv-r9-288c-n15-model-23-racon-hax',
    './e-coli-n15-model-23-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n15-model-23-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n15-model-23-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n15-model-23-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:07:31 Time:  0:07:31
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3903 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:16:21
# Creating dataset with neighbourhood ...
#   3% (695758 of 19138428) |              | Elapsed Time: 0:00:38 ETA:   2:11:00
# Creating dataset with neighbourhood ...
#  10% (1994352 of 19138428) |#            | Elapsed Time: 0:01:50 ETA:   3:51:56
# Creating dataset with neighbourhood ...
#  15% (3054886 of 19138428) |##           | Elapsed Time: 0:02:48 ETA:   2:20:48
# Creating dataset with neighbourhood ...
#  19% (3794306 of 19138428) |##           | Elapsed Time: 0:03:29 ETA:   2:55:31
# Creating dataset with neighbourhood ...
#  32% (6196252 of 19138428) |####         | Elapsed Time: 0:05:39 ETA:   4:02:51
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n15 model-24 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-s-cerevisiae-racon-hax/model-24.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 15
output_dirs = [
    './s-cerv-r7-288c-n15-model-24-racon-hax',
    './s-cerv-r9-288c-n15-model-24-racon-hax',
    './e-coli-n15-model-24-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n15-model-24-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n15-model-24-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n15-model-24-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----

# %% [markdown]
# ## n20 model-24 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae-racon-hax/model-24.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 20
output_dirs = [
    './s-cerv-r7-288c-n20-model-24-racon-hax',
    './s-cerv-r9-288c-n20-model-24-racon-hax',
    './e-coli-n20-model-24-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n20-model-24-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n20-model-24-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n20-model-24-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:08:02 Time:  0:08:02
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3694 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:17:17
# Creating dataset with neighbourhood ...
#   3% (695432 of 19138428) |              | Elapsed Time: 0:00:41 ETA:   3:53:32
# Creating dataset with neighbourhood ...
#  10% (1994012 of 19138428) |#            | Elapsed Time: 0:01:58 ETA:   4:44:14
# Creating dataset with neighbourhood ...
#  15% (3054639 of 19138428) |##           | Elapsed Time: 0:03:00 ETA:   4:32:35
# Creating dataset with neighbourhood ...
#  19% (3794378 of 19138428) |##           | Elapsed Time: 0:03:45 ETA:   3:03:31
# Creating dataset with neighbourhood ...
#  32% (6195832 of 19138428) |####         | Elapsed Time: 0:06:05 ETA:   5:42:26
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n20 model-23 trained od s-cerv mix R7&9 racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-s-cerevisiae-racon-hax/model-23.h5'
reads_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r7_288c.fastq',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/scerevisiae_r9_288c.fastq',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/ecoli_map006.fastq'
]
assembly_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/iter2.fasta',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/iter2.fasta'
]
reference_paths = [
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/saccharomyces/cerevisiae/saccharomyces_cerevisiae_reference.fasta',
    '/home/data/oxford_nanopore/bacteria/escherichia/coli/escherichia_coli_reference.fasta'
]
sam_file_paths = [
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r7-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/s-cerevisiae-r9-288c/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/escherichia-coli-ecoli_map006/reads-to-asm.sam'
]
neighbourhood_size = 20
output_dirs = [
    './s-cerv-r7-288c-n20-model-23-racon-hax',
    './s-cerv-r9-288c-n20-model-23-racon-hax',
    './e-coli-n20-model-23-racon-hax'
]
result_file_paths = [
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r7-288c/n20-model-23-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/saccharomyces-cerevisiae-r9-288c/n20-model-23-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/s-cerevisiae-r7-r9-dataset/escherichia-coli/n20-model-23-all-contigs-racon-hax-report.txt'
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (19138428 of 19138428) |############| Elapsed Time: 0:08:19 Time:  0:08:19
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3552 of 19138428) |                | Elapsed Time: 0:00:00 ETA:   0:17:58
# Creating dataset with neighbourhood ...
#   3% (695439 of 19138428) |              | Elapsed Time: 0:00:41 ETA:   4:05:20
# Creating dataset with neighbourhood ...
#  10% (1994098 of 19138428) |#            | Elapsed Time: 0:01:58 ETA:   6:04:41
# Creating dataset with neighbourhood ...
#  15% (3054617 of 19138428) |##           | Elapsed Time: 0:03:00 ETA:   3:45:08
# Creating dataset with neighbourhood ...
#  19% (3794405 of 19138428) |##           | Elapsed Time: 0:03:45 ETA:   3:21:15
# Creating dataset with neighbourhood ...
#  32% (6195829 of 19138428) |####         | Elapsed Time: 0:06:05 ETA:   6:03:49
# Creating dataset with neighbourhood ...
# ...

# %% [markdown]
# ## n15 model-11 trained on f-bact racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-f-bacterium-racon-hax/model-11-repeat.h5'
reads_paths = [
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-23726/SRR6780922.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/periodonticum/SRR6780924.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/ulcerans/SRR6780916.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/varium/SRR6780912.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/gonidiaformans/SRR6780920.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/mortiferum/SRR6780914.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/necrophorum/SRR6780918.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-25586/SRR6830111.fastq',
]
assembly_paths = [
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-23726/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-periodonticum/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-ulcerans/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-varium/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-gonidiaformans/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-mortiferum/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-necrophorum/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-25586/iter2.fasta'
    
]
reference_paths = [
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-23726/f-nucleatum-23726.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/periodonticum/f-periodonticum.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/ulcerans/f-ulcerans.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/varium/f-varium.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/gonidiaformans/f-gonidiaformans.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/mortiferum/f-motriferum.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/necrophorum/f-necrophorum.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-25586/f-nucleatum-25586.fasta',
]
sam_file_paths = [
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-23726/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-periodonticum/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-ulcerans/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-varium/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-gonidiaformans/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-mortiferum/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-necrophorum/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-25586/reads-to-asm.sam',
]
neighbourhood_size = 15
output_dirs = [
#     './f-bact-nucleatum-23726-n15-model-11-racon-hax',
#     './f-bact-periodonticum-n15-model-11-racon-hax',
#     './f-bact-ulcerans-n15-model-11-racon-hax',
#     './f-bact-varium-n15-model-11-racon-hax',
    './f-bact-gonidiaformans-n15-model-11-racon-hax',
    './f-bact-mortiferum-n15-model-11-racon-hax',
    './f-bact-necrophorum-n15-model-11-racon-hax',
    './f-bact-nucleatum-25586-n15-model-11-racon-hax',
]
result_file_paths = [
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/nucleatum-23726/n15-model-11-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/periodonticum/n15-model-11-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/ulcerans/n15-model-11-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/varium/n15-model-11-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/gonidiaformans/n15-model-11-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/mortiferum/n15-model-11-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/necrophorum/n15-model-11-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/nucleatum-25586/n15-model-11-all-contigs-racon-hax-report.txt',
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (2450213 of 2450213) |##############| Elapsed Time: 0:01:01 Time:  0:01:01
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3714 of 2450213) |                 | Elapsed Time: 0:00:00 ETA:   0:02:11
# Creating dataset with neighbourhood ...
# 100% (2450213 of 2450213) |##############| Elapsed Time: 0:02:15 Time:  0:02:15
# ----> Load model and make predictions (consensus). <----
# ----> Create consensus summary. <----
# ----> Create pileups from assembly. <----
# 100% (3811911 of 3811911) |##############| Elapsed Time: 0:01:30 Time:  0:01:30
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3651 of 3811911) |                 | Elapsed Time: 0:00:00 ETA:   0:03:28
# Creating dataset with neighbourhood ...
# 100% (3811911 of 3811911) |##############| Elapsed Time: 0:03:29 Time:  0:03:29
# ----> Load model and make predictions (consensus). <----
# ----> Create consensus summary. <----
# ...

# %% [markdown]
# ## n20 model-11 trained on f-bact racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-f-bacterium-racon-hax/model-11-repeat.h5'
reads_paths = [
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-23726/SRR6780922.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/periodonticum/SRR6780924.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/ulcerans/SRR6780916.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/varium/SRR6780912.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/gonidiaformans/SRR6780920.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/mortiferum/SRR6780914.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/necrophorum/SRR6780918.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-25586/SRR6830111.fastq',
]
assembly_paths = [
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-23726/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-periodonticum/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-ulcerans/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-varium/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-gonidiaformans/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-mortiferum/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-necrophorum/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-25586/iter2.fasta'
    
]
reference_paths = [
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-23726/f-nucleatum-23726.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/periodonticum/f-periodonticum.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/ulcerans/f-ulcerans.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/varium/f-varium.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/gonidiaformans/f-gonidiaformans.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/mortiferum/f-motriferum.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/necrophorum/f-necrophorum.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-25586/f-nucleatum-25586.fasta',
]
sam_file_paths = [
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-23726/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-periodonticum/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-ulcerans/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-varium/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-gonidiaformans/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-mortiferum/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-necrophorum/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-25586/reads-to-asm.sam',
]
neighbourhood_size = 20
output_dirs = [
#     './f-bact-nucleatum-23726-n15-model-11-racon-hax',
#     './f-bact-periodonticum-n15-model-11-racon-hax',
#     './f-bact-ulcerans-n15-model-11-racon-hax',
#     './f-bact-varium-n15-model-11-racon-hax',
    './f-bact-gonidiaformans-n20-model-11-racon-hax',
    './f-bact-mortiferum-n20-model-11-racon-hax',
    './f-bact-necrophorum-n20-model-11-racon-hax',
    './f-bact-nucleatum-25586-n20-model-11-racon-hax',
]
result_file_paths = [
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/nucleatum-23726/n15-model-11-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/periodonticum/n15-model-11-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/ulcerans/n15-model-11-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/varium/n15-model-11-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/gonidiaformans/n20-model-11-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/mortiferum/n20-model-11-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/necrophorum/n20-model-11-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/nucleatum-25586/n20-model-11-all-contigs-racon-hax-report.txt',
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (2450213 of 2450213) |##############| Elapsed Time: 0:00:59 Time:  0:00:59
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3697 of 2450213) |                 | Elapsed Time: 0:00:00 ETA:   0:02:12
# Creating dataset with neighbourhood ...
# 100% (2450213 of 2450213) |##############| Elapsed Time: 0:02:19 Time:  0:02:19
# ----> Load model and make predictions (consensus). <----
# ----> Create consensus summary. <----
# ----> Create pileups from assembly. <----
# 100% (3811911 of 3811911) |##############| Elapsed Time: 0:01:27 Time:  0:01:27
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3564 of 3811911) |                 | Elapsed Time: 0:00:00 ETA:   0:03:33
# Creating dataset with neighbourhood ...
# 100% (3811911 of 3811911) |##############| Elapsed Time: 0:03:37 Time:  0:03:37
# ----> Load model and make predictions (consensus). <----
# ----> Create consensus summary. <----
# ...

# %% [markdown]
# ## n20 model-23 trained on f-bact racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-f-bacterium-racon-hax/model-23-repeat.h5'
reads_paths = [
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-23726/SRR6780922.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/periodonticum/SRR6780924.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/ulcerans/SRR6780916.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/varium/SRR6780912.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/gonidiaformans/SRR6780920.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/mortiferum/SRR6780914.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/necrophorum/SRR6780918.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-25586/SRR6830111.fastq',
]
assembly_paths = [
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-23726/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-periodonticum/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-ulcerans/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-varium/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-gonidiaformans/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-mortiferum/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-necrophorum/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-25586/iter2.fasta'
    
]
reference_paths = [
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-23726/f-nucleatum-23726.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/periodonticum/f-periodonticum.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/ulcerans/f-ulcerans.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/varium/f-varium.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/gonidiaformans/f-gonidiaformans.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/mortiferum/f-motriferum.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/necrophorum/f-necrophorum.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-25586/f-nucleatum-25586.fasta',
]
sam_file_paths = [
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-23726/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-periodonticum/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-ulcerans/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-varium/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-gonidiaformans/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-mortiferum/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-necrophorum/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-25586/reads-to-asm.sam',
]
neighbourhood_size = 20
output_dirs = [
#     './f-bact-nucleatum-23726-n15-model-11-racon-hax',
#     './f-bact-periodonticum-n15-model-11-racon-hax',
#     './f-bact-ulcerans-n15-model-11-racon-hax',
#     './f-bact-varium-n15-model-11-racon-hax',
    './f-bact-gonidiaformans-n20-model-23-racon-hax',
    './f-bact-mortiferum-n20-model-23-racon-hax',
    './f-bact-necrophorum-n20-model-23-racon-hax',
    './f-bact-nucleatum-25586-n20-model-23-racon-hax',
]
result_file_paths = [
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/nucleatum-23726/n15-model-11-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/periodonticum/n15-model-11-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/ulcerans/n15-model-11-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/varium/n15-model-11-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/gonidiaformans/n20-model-23-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/mortiferum/n20-model-23-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/necrophorum/n20-model-23-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/nucleatum-25586/n20-model-23-all-contigs-racon-hax-report.txt',
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (2450213 of 2450213) |##############| Elapsed Time: 0:01:01 Time:  0:01:01
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3747 of 2450213) |                 | Elapsed Time: 0:00:00 ETA:   0:02:10
# Creating dataset with neighbourhood ...
# 100% (2450213 of 2450213) |##############| Elapsed Time: 0:02:19 Time:  0:02:19
# ----> Load model and make predictions (consensus). <----
# ----> Create consensus summary. <----
# ----> Create pileups from assembly. <----
# 100% (3811911 of 3811911) |##############| Elapsed Time: 0:01:24 Time:  0:01:24
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3910 of 3811911) |                 | Elapsed Time: 0:00:00 ETA:   0:03:14
# Creating dataset with neighbourhood ...
# 100% (3811911 of 3811911) |##############| Elapsed Time: 0:03:33 Time:  0:03:33
# ----> Load model and make predictions (consensus). <----
# ----> Create consensus summary. <----
# ...

# %% [markdown]
# ## n20 model-23-cw trained on f-bact racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-f-bacterium-racon-hax/model-23-cw.h5'
reads_paths = [
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-23726/SRR6780922.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/periodonticum/SRR6780924.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/ulcerans/SRR6780916.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/varium/SRR6780912.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/gonidiaformans/SRR6780920.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/mortiferum/SRR6780914.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/necrophorum/SRR6780918.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-25586/SRR6830111.fastq',
]
assembly_paths = [
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-23726/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-periodonticum/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-ulcerans/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-varium/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-gonidiaformans/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-mortiferum/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-necrophorum/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-25586/iter2.fasta'
    
]
reference_paths = [
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-23726/f-nucleatum-23726.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/periodonticum/f-periodonticum.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/ulcerans/f-ulcerans.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/varium/f-varium.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/gonidiaformans/f-gonidiaformans.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/mortiferum/f-motriferum.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/necrophorum/f-necrophorum.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-25586/f-nucleatum-25586.fasta',
]
sam_file_paths = [
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-23726/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-periodonticum/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-ulcerans/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-varium/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-gonidiaformans/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-mortiferum/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-necrophorum/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-25586/reads-to-asm.sam',
]
neighbourhood_size = 20
output_dirs = [
#     './f-bact-nucleatum-23726-n20-model-23-cw-racon-hax',
#     './f-bact-periodonticum-n20-model-23-cw-racon-hax',
#     './f-bact-ulcerans-n20-model-23-cw-racon-hax',
    './f-bact-varium-n20-model-23-cw-racon-hax',
#     './f-bact-gonidiaformans-n20-model-23-cw-racon-hax',
#     './f-bact-mortiferum-n20-model-23-cw-racon-hax',
#     './f-bact-necrophorum-n20-model-23-cw-racon-hax',
#     './f-bact-nucleatum-25586-n20-model-23-cw-racon-hax',
]
result_file_paths = [
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/nucleatum-23726/n20-model-23-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/periodonticum/n20-model-23-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/ulcerans/n20-model-23-cw-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/varium/n20-model-23-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/gonidiaformans/n20-model-23-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/mortiferum/n20-model-23-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/necrophorum/n20-model-23-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/nucleatum-25586/n20-model-23-cw-all-contigs-racon-hax-report.txt',
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp-gpu-1'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (4279452 of 4279452) |##############| Elapsed Time: 0:01:38 Time:  0:01:38
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3814 of 4279452) |                 | Elapsed Time: 0:00:00 ETA:   0:03:44
# Creating dataset with neighbourhood ...
#  77% (3314293 of 4279452) |##########    | Elapsed Time: 0:03:07 ETA:   0:42:28
# Creating dataset with neighbourhood ...
#  97% (4185106 of 4279452) |############# | Elapsed Time: 0:03:57 ETA:   0:01:01
# Creating dataset with neighbourhood ...
# 100% (4279452 of 4279452) |##############| Elapsed Time: 0:04:02 Time:  0:04:02
# ----> Load model and make predictions (consensus). <----
# ----> Create consensus summary. <----

# %% [markdown]
# ## n20 model-24-cw trained on f-bact racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n20-f-bacterium-racon-hax/model-24-cw.h5'
reads_paths = [
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-23726/SRR6780922.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/periodonticum/SRR6780924.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/ulcerans/SRR6780916.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/varium/SRR6780912.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/gonidiaformans/SRR6780920.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/mortiferum/SRR6780914.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/necrophorum/SRR6780918.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-25586/SRR6830111.fastq',
]
assembly_paths = [
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-23726/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-periodonticum/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-ulcerans/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-varium/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-gonidiaformans/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-mortiferum/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-necrophorum/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-25586/iter2.fasta'
    
]
reference_paths = [
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-23726/f-nucleatum-23726.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/periodonticum/f-periodonticum.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/ulcerans/f-ulcerans.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/varium/f-varium.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/gonidiaformans/f-gonidiaformans.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/mortiferum/f-motriferum.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/necrophorum/f-necrophorum.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-25586/f-nucleatum-25586.fasta',
]
sam_file_paths = [
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-23726/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-periodonticum/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-ulcerans/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-varium/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-gonidiaformans/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-mortiferum/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-necrophorum/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-25586/reads-to-asm.sam',
]
neighbourhood_size = 20
output_dirs = [
#     './f-bact-nucleatum-23726-n20-model-24-cw-racon-hax',
#     './f-bact-periodonticum-n20-model-24-cw-racon-hax',
#     './f-bact-ulcerans-n20-model-24-cw-racon-hax',
    './f-bact-varium-n20-model-24-cw-racon-hax',
#     './f-bact-gonidiaformans-n20-model-24-cw-racon-hax',
#     './f-bact-mortiferum-n20-model-24-cw-racon-hax',
#     './f-bact-necrophorum-n20-model-24-cw-racon-hax',
#     './f-bact-nucleatum-25586-n20-model-24-cw-racon-hax',
]
result_file_paths = [
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/nucleatum-23726/n20-model-24-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/periodonticum/n20-model-24-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/ulcerans/n20-model-24-cw-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/varium/n20-model-24-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/gonidiaformans/n20-model-24-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/mortiferum/n20-model-24-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/necrophorum/n20-model-24-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/nucleatum-25586/n20-model-24-cw-all-contigs-racon-hax-report.txt',
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp-gpu-1'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (4279452 of 4279452) |##############| Elapsed Time: 0:01:43 Time:  0:01:43
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3754 of 4279452) |                 | Elapsed Time: 0:00:00 ETA:   0:03:48
# Creating dataset with neighbourhood ...
#  77% (3313342 of 4279452) |##########    | Elapsed Time: 0:03:14 ETA:   0:46:09
# Creating dataset with neighbourhood ...
#  97% (4184976 of 4279452) |############# | Elapsed Time: 0:04:06 ETA:   0:00:58
# Creating dataset with neighbourhood ...
# 100% (4279452 of 4279452) |##############| Elapsed Time: 0:04:11 Time:  0:04:11
# ----> Load model and make predictions (consensus). <----
# ----> Create consensus summary. <----

# %% [markdown]
# ## n15 model-24-cw trained on f-bact racon-hax

# %%
model_path = '/home/diplomski-rad/blade/ont/datasets/n15-f-bacterium-racon-hax/model-24-cw.h5'
reads_paths = [
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-23726/SRR6780922.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/periodonticum/SRR6780924.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/ulcerans/SRR6780916.fastq',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/varium/SRR6780912.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/gonidiaformans/SRR6780920.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/mortiferum/SRR6780914.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/necrophorum/SRR6780918.fastq',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-25586/SRR6830111.fastq',
]
assembly_paths = [
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-23726/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-periodonticum/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-ulcerans/iter2.fasta',
    '/home/diplomski-rad/blade/ont/fusobacterium-varium/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-gonidiaformans/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-mortiferum/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-necrophorum/iter2.fasta',
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-25586/iter2.fasta'
    
]
reference_paths = [
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-23726/f-nucleatum-23726.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/periodonticum/f-periodonticum.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/ulcerans/f-ulcerans.fasta',
    '/home/data/oxford_nanopore/bacteria/fusobacterium/varium/f-varium.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/gonidiaformans/f-gonidiaformans.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/mortiferum/f-motriferum.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/necrophorum/f-necrophorum.fasta',
#     '/home/data/oxford_nanopore/bacteria/fusobacterium/nucleatum-25586/f-nucleatum-25586.fasta',
]
sam_file_paths = [
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-23726/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-periodonticum/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-ulcerans/reads-to-asm.sam',
    '/home/diplomski-rad/blade/ont/fusobacterium-varium/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-gonidiaformans/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-mortiferum/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-necrophorum/reads-to-asm.sam',
#     '/home/diplomski-rad/blade/ont/fusobacterium-nucleatum-25586/reads-to-asm.sam',
]
neighbourhood_size = 15
output_dirs = [
#     './f-bact-nucleatum-23726-n15-model-24-cw-racon-hax',
#     './f-bact-periodonticum-n15-model-24-cw-racon-hax',
#     './f-bact-ulcerans-n15-model-24-cw-racon-hax',
    './f-bact-varium-n15-model-24-cw-racon-hax',
#     './f-bact-gonidiaformans-n15-model-24-cw-racon-hax',
#     './f-bact-mortiferum-n15-model-24-cw-racon-hax',
#     './f-bact-necrophorum-n15-model-24-cw-racon-hax',
#     './f-bact-nucleatum-25586-n15-model-24-cw-racon-hax',
]
result_file_paths = [
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/nucleatum-23726/n15-model-24-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/periodonticum/n15-model-24-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/ulcerans/n15-model-24-cw-all-contigs-racon-hax-report.txt',
    '/home/diplomski-rad/results/ont/fusobacterium-dataset/varium/n15-model-24-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/gonidiaformans/n15-model-24-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/mortiferum/n15-model-24-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/necrophorum/n15-model-24-cw-all-contigs-racon-hax-report.txt',
#     '/home/diplomski-rad/results/ont/fusobacterium-dataset/nucleatum-25586/n15-model-24-cw-all-contigs-racon-hax-report.txt',
]
tools_dir = '/home/diplomski-rad/'
racon_hax_output_dir = './racon-hax-tmp-gpu-1'
num_threads = 12

for reads_path, assembly_path, reference_path, sam_file_path, output_dir, result_file_path in \
    zip(reads_paths, assembly_paths, reference_paths, sam_file_paths, output_dirs, result_file_paths):
    
    pileup_generator = pileups.RaconMSAGenerator(
        reads_path,
        sam_file_path,
        assembly_path,
        mode='inference',
        tools_dir=tools_dir,
        racon_hax_output_dir=racon_hax_output_dir,
        num_threads=num_threads
    )
    
    inference.make_consensus(
        model_path, 
        reference_path,
        pileup_generator,
        neighbourhood_size,
        output_dir,
        tools_dir,
        result_file_path)
# Out:
# ----> Create pileups from assembly. <----
# 100% (4279452 of 4279452) |##############| Elapsed Time: 0:01:40 Time:  0:01:40
# ----> Create dataset with neighbourhood from pileups. <----
#   0% (3820 of 4279452) |                 | Elapsed Time: 0:00:00 ETA:   0:03:44
# Creating dataset with neighbourhood ...
#  77% (3312383 of 4279452) |##########    | Elapsed Time: 0:03:02 ETA:   1:13:21
# Creating dataset with neighbourhood ...
#  97% (4185176 of 4279452) |############# | Elapsed Time: 0:03:50 ETA:   0:00:47
# Creating dataset with neighbourhood ...
# 100% (4279452 of 4279452) |##############| Elapsed Time: 0:03:55 Time:  0:03:55
# ----> Load model and make predictions (consensus). <----
# ----> Create consensus summary. <----
