# %%
import numpy as np

from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Input
from keras.utils import np_utils
from keras.models import Model

# %%
X, y = np.load('pysam-dataset-n3-X.npy'), np.load('pysam-dataset-n3-y.npy')

# %%
print(X.shape)
print(y.shape)
# Out:
# (3573946, 7, 4)
# (3573946, 4)

# %%
from sklearn.model_selection import train_test_split

X_train, X_validate, y_train, y_validate = train_test_split(X, y, test_size=0.10)
print(X_train.shape, X_validate.shape, y_train.shape, y_validate.shape)
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# (3216551, 7, 4) (357395, 7, 4) (3216551, 4) (357395, 4)

# %%
model = InceptionResNetV2(weights=None, include_top=False, input_tensor=Input(shape=(1, 7, 4)))
model.summary()

# input_layer = Input(shape=(7, 4))
# output_layer = model(input_layer)


# predictions = Dense(25, activation='softmax')(output_layer)

# model = Model(inputs=input_layer, outputs=predictions)

# model.compile(loss='categorical_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])

# batch_size = 100000
# epochs = 3

# model.fit(X_train, y_train, batch_size=10, epochs=epochs, validation_data=(X_validate, y_validate))
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, require_shape_fn)
#     685           graph_def_version, node_def_str, input_shapes, input_tensors,
# --> 686           input_tensors_as_shapes, status)
#     687   except errors.InvalidArgumentError as err:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     515             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 516             c_api.TF_GetCode(self.status.status))
#     517     # Delete the underlying status object from memory otherwise it stays alive
#
# ...

# %%
from keras.applications.vgg16 import VGG16

model_vgg16_conv = VGG16(weights='imagenet', include_top=False)
#model_vgg16_conv.summary()

#Create your own input format
keras_input = Input(shape=(7, 4, 3), name = 'image_input')
#Use the generated model 
output_vgg16_conv = model_vgg16_conv(keras_input)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/common_shapes.py in _call_cpp_shape_fn_impl(op, input_tensors_needed, input_tensors_as_shapes_needed, require_shape_fn)
#     685           graph_def_version, node_def_str, input_shapes, input_tensors,
# --> 686           input_tensors_as_shapes, status)
#     687   except errors.InvalidArgumentError as err:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     515             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 516             c_api.TF_GetCode(self.status.status))
#     517     # Delete the underlying status object from memory otherwise it stays alive
#
# ...

# %%
from keras.applications.vgg16 import VGG16

model_vgg16_conv = VGG16(weights=None, include_top=False, input_shape=(7, 4, 1))
#model_vgg16_conv.summary()

#Create your own input format
# keras_input = Input(shape=(7, 4, 3), name = 'image_input')
# #Use the generated model 
# output_vgg16_conv = model_vgg16_conv(keras_input)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-e302d214ec98> in <module>()
#       1 from keras.applications.vgg16 import VGG16
#       2
# ----> 3 model_vgg16_conv = VGG16(weights=None, include_top=False, input_shape=(7, 4, 1))
#       4 #model_vgg16_conv.summary()
#       5
#
# ~/.local/lib/python3.5/site-packages/keras/applications/vgg16.py in VGG16(include_top, weights, input_tensor, input_shape, pooling, classes)
#     104                                       data_format=K.image_data_format(),
#     105                                       require_flatten=include_top,
# --> 106                                       weights=weights)
#     107
#     108     if input_tensor is None:
#
# ...
