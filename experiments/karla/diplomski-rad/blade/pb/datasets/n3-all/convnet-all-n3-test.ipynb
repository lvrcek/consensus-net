# %%
import numpy as np

import sys
module_path = '/home/diplomski-rad/consensus-net/src/python/dataset/'
if module_path not in sys.path:
    print('Adding dataset module.')
    sys.path.append(module_path)

import dataset

# %%
X, y, X_train, X_validate, y_train, y_validate = dataset.read_dataset_and_reshape_for_conv(
    './pysam-all-dataset-n3-X.npy', './pysam-all-dataset-n3-y.npy', 0.1)
# Out:
#   0% (6054 of 16691589) |                | Elapsed Time: 0:00:00 ETA:   0:09:11
# X shape before reshaping: (16691589, 7, 4)
# y shape before reshaping: (16691589, 4)
# 100% (16691589 of 16691589) |############| Elapsed Time: 0:01:29 Time:  0:01:29
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9159047b6a88> in <module>()
#       1 X, y, X_train, X_validate, y_train, y_validate = dataset.read_dataset_and_reshape_for_conv(
# ----> 2     './pysam-all-dataset-n3-X.npy', './pysam-all-dataset-n3-y.npy', 0.1)
#
# /home/diplomski-rad/consensus-net/src/python/dataset/dataset.py in read_dataset_and_reshape_for_conv(path_X, path_y, validation_size)
#      42             new_xi = np.dstack(
#      43                 [xi[:, col_index].reshape(neighbourhood_size, 1)
# ---> 44                  for col_index in range(num_columns)]
#      45             )
#      46             new_X.append(new_xi)
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/shape_base.py in dstack(tup)
#     419
#     420     """
# --> 421     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
#     422
#     423 def _replace_zero_by_x_arrays(sub_arys):
#
# /usr/local/lib/python3.5/dist-packages/numpy/lib/shape_base.py in <listcomp>(.0)
#     419
#     420     """
# --> 421     return _nx.concatenate([atleast_3d(_m) for _m in tup], 2)
#     422
#     423 def _replace_zero_by_x_arrays(sub_arys):
#
# /usr/local/lib/python3.5/dist-packages/numpy/core/shape_base.py in atleast_3d(*arys)
#     170             result = ary[newaxis,:, newaxis]
#     171         elif ary.ndim == 2:
# --> 172             result = ary[:,:, newaxis]
#     173         else:
#     174             result = ary
#
# KeyboardInterrupt:

# %%
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Input
from keras.layers import Conv1D, MaxPooling1D, Conv2D
# Out:
# /home/ajuric/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
input_layer = Input(shape=(7, 1, 4))
conv_1 = Conv2D(filters=10, kernel_size=3, padding='same', activation='relu')(input_layer)

flatten = Flatten()(conv_1)
predictions = Dense(4, activation='softmax')(flatten)

model = Model(input_layer, predictions)

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(model.summary())

batch_size = 10000
epochs = 200

model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_validate, y_validate))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 7, 1, 4)           0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 1, 10)          370
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 70)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 4)                 284
# =================================================================
# Total params: 654
# Trainable params: 654
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 15022430 samples, validate on 1669159 samples
# Epoch 1/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.3540 - acc: 0.9674 - val_loss: 0.0624 - val_acc: 0.9880
# Epoch 2/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0527 - acc: 0.9883 - val_loss: 0.0443 - val_acc: 0.9892
# Epoch 3/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0371 - acc: 0.9904 - val_loss: 0.0306 - val_acc: 0.9919
# Epoch 4/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0275 - acc: 0.9926 - val_loss: 0.0248 - val_acc: 0.9932
# Epoch 5/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0238 - acc: 0.9935 - val_loss: 0.0229 - val_acc: 0.9936
# Epoch 6/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0215 - acc: 0.9939 - val_loss: 0.0199 - val_acc: 0.9941
# Epoch 7/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0196 - acc: 0.9942 - val_loss: 0.0190 - val_acc: 0.9943
# Epoch 8/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0190 - acc: 0.9943 - val_loss: 0.0182 - val_acc: 0.9945
# Epoch 9/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0182 - acc: 0.9945 - val_loss: 0.0177 - val_acc: 0.9946
# Epoch 10/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0177 - acc: 0.9945 - val_loss: 0.0173 - val_acc: 0.9946
# Epoch 11/200
#  7600000/15022430 [==============>...............] - ETA: 7s - loss: 0.0175 - acc: 0.9946
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-b6ad36c4d3e3> in <module>()
#      16 epochs = 200
#      17
# ---> 18 model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_validate, y_validate))
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# ~/.local/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1338         else:
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#    1342     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
input_layer = Input(shape=(7, 1, 4))
conv_1 = Conv2D(filters=20, kernel_size=3, padding='same', activation='relu')(input_layer)

flatten = Flatten()(conv_1)
predictions = Dense(4, activation='softmax')(flatten)

model = Model(input_layer, predictions)

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(model.summary())

batch_size = 10000
epochs = 200

model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_validate, y_validate))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 7, 1, 4)           0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 7, 1, 20)          740
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 140)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 4)                 564
# =================================================================
# Total params: 1,304
# Trainable params: 1,304
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 15022430 samples, validate on 1669159 samples
# Epoch 1/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.2108 - acc: 0.9763 - val_loss: 0.0482 - val_acc: 0.9893
# Epoch 2/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0346 - acc: 0.9912 - val_loss: 0.0252 - val_acc: 0.9931
# Epoch 3/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0223 - acc: 0.9936 - val_loss: 0.0199 - val_acc: 0.9941
# Epoch 4/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0185 - acc: 0.9944 - val_loss: 0.0169 - val_acc: 0.9947
# Epoch 5/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0160 - acc: 0.9950 - val_loss: 0.0150 - val_acc: 0.9952
# Epoch 6/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0137 - acc: 0.9956 - val_loss: 0.0131 - val_acc: 0.9958
# Epoch 7/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0128 - acc: 0.9959 - val_loss: 0.0123 - val_acc: 0.9961
# Epoch 8/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0120 - acc: 0.9962 - val_loss: 0.0123 - val_acc: 0.9961
# Epoch 9/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0116 - acc: 0.9963 - val_loss: 0.0114 - val_acc: 0.9964
# Epoch 10/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0113 - acc: 0.9964 - val_loss: 0.0112 - val_acc: 0.9965
# Epoch 11/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0110 - acc: 0.9965 - val_loss: 0.0109 - val_acc: 0.9965
# Epoch 12/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0108 - acc: 0.9966 - val_loss: 0.0110 - val_acc: 0.9965
# Epoch 13/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0107 - acc: 0.9966 - val_loss: 0.0105 - val_acc: 0.9967
# Epoch 14/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0105 - acc: 0.9967 - val_loss: 0.0103 - val_acc: 0.9968
# Epoch 15/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0103 - acc: 0.9968 - val_loss: 0.0106 - val_acc: 0.9967
# Epoch 16/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0102 - acc: 0.9968 - val_loss: 0.0102 - val_acc: 0.9968
# Epoch 17/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0101 - acc: 0.9968 - val_loss: 0.0100 - val_acc: 0.9968
# Epoch 18/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0101 - acc: 0.9969 - val_loss: 0.0098 - val_acc: 0.9969
# Epoch 19/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0100 - acc: 0.9969 - val_loss: 0.0098 - val_acc: 0.9969
# Epoch 20/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0100 - acc: 0.9969 - val_loss: 0.0101 - val_acc: 0.9968
# Epoch 21/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0099 - acc: 0.9969 - val_loss: 0.0098 - val_acc: 0.9969
# Epoch 22/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0098 - acc: 0.9969 - val_loss: 0.0098 - val_acc: 0.9970
# Epoch 23/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0098 - acc: 0.9969 - val_loss: 0.0098 - val_acc: 0.9969
# Epoch 24/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0098 - acc: 0.9969 - val_loss: 0.0097 - val_acc: 0.9970
# Epoch 25/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0098 - acc: 0.9969 - val_loss: 0.0097 - val_acc: 0.9970
# Epoch 26/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0098 - acc: 0.9969 - val_loss: 0.0097 - val_acc: 0.9970
# Epoch 27/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0098 - acc: 0.9970 - val_loss: 0.0097 - val_acc: 0.9970
# Epoch 28/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0098 - acc: 0.9970 - val_loss: 0.0098 - val_acc: 0.9970
# Epoch 29/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0098 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 30/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0098 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 31/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0098 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 32/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0098 - val_acc: 0.9969
# Epoch 33/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 34/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 35/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0102 - val_acc: 0.9968
# Epoch 36/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 37/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0095 - val_acc: 0.9970
# Epoch 38/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0098 - val_acc: 0.9969
# Epoch 39/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 40/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0097 - val_acc: 0.9970
# Epoch 41/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 42/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0097 - val_acc: 0.9970
# Epoch 43/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0095 - val_acc: 0.9970
# Epoch 44/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0104 - val_acc: 0.9968
# Epoch 45/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 46/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0094 - val_acc: 0.9970
# Epoch 47/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0095 - val_acc: 0.9970
# Epoch 48/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0097 - val_acc: 0.9970
# Epoch 49/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0098 - val_acc: 0.9970
# Epoch 50/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 51/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 52/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0094 - val_acc: 0.9970
# Epoch 53/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0095 - val_acc: 0.9970
# Epoch 54/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0097 - val_acc: 0.9970
# Epoch 55/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 56/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0095 - val_acc: 0.9970
# Epoch 57/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0094 - val_acc: 0.9970
# Epoch 58/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 59/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0094 - val_acc: 0.9971
# Epoch 60/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 61/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0094 - val_acc: 0.9970
# Epoch 62/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0097 - val_acc: 0.9970
# Epoch 63/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0097 - acc: 0.9970 - val_loss: 0.0095 - val_acc: 0.9970
# Epoch 64/200
# 15022430/15022430 [==============================] - 16s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0097 - val_acc: 0.9969
# Epoch 65/200
# 15022430/15022430 [==============================] - 17s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 66/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0099 - val_acc: 0.9969
# Epoch 67/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0095 - val_acc: 0.9970
# Epoch 68/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0097 - val_acc: 0.9969
# Epoch 69/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 70/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0097 - val_acc: 0.9970
# Epoch 71/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0094 - val_acc: 0.9971
# Epoch 72/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0096 - val_acc: 0.9970
# Epoch 73/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0094 - val_acc: 0.9970
# Epoch 74/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0095 - val_acc: 0.9970
# Epoch 75/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0099 - val_acc: 0.9969
# Epoch 76/200
# 15022430/15022430 [==============================] - 15s 1us/step - loss: 0.0096 - acc: 0.9970 - val_loss: 0.0098 - val_acc: 0.9969
# Epoch 77/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-047dcdeb45f6> in <module>()
#      16 epochs = 200
#      17
# ---> 18 model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_validate, y_validate))
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     index_array = _batch_shuffle(index_array, batch_size)
#    1212                 elif shuffle:
# -> 1213                     np.random.shuffle(index_array)
#    1214
#    1215                 batches = _make_batches(num_train_samples, batch_size)
#
# KeyboardInterrupt:

# %%
input_layer = Input(shape=(7, 1, 4))
conv_1 = Conv2D(filters=10, kernel_size=3, padding='same', activation='relu')(input_layer)
conv_2 = Conv2D(filters=5, kernel_size=3, padding='same', activation='relu')(conv_1)

flatten = Flatten()(conv_2)
predictions = Dense(4, activation='softmax')(flatten)

model = Model(input_layer, predictions)

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(model.summary())

batch_size = 10000
epochs = 200

model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_validate, y_validate))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        (None, 7, 1, 4)           0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 7, 1, 10)          370
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 7, 1, 5)           455
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 35)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 4)                 144
# =================================================================
# Total params: 969
# Trainable params: 969
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 15022430 samples, validate on 1669159 samples
# Epoch 1/200
# 15022430/15022430 [==============================] - 19s 1us/step - loss: 0.1803 - acc: 0.9627 - val_loss: 0.0546 - val_acc: 0.9887
# Epoch 2/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0472 - acc: 0.9891 - val_loss: 0.0363 - val_acc: 0.9903
# Epoch 3/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0324 - acc: 0.9910 - val_loss: 0.0293 - val_acc: 0.9917
# Epoch 4/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0283 - acc: 0.9918 - val_loss: 0.0265 - val_acc: 0.9921
# Epoch 5/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0254 - acc: 0.9923 - val_loss: 0.0241 - val_acc: 0.9927
# Epoch 6/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0226 - acc: 0.9929 - val_loss: 0.0216 - val_acc: 0.9931
# Epoch 7/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0209 - acc: 0.9933 - val_loss: 0.0198 - val_acc: 0.9936
# Epoch 8/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0197 - acc: 0.9935 - val_loss: 0.0191 - val_acc: 0.9938
# Epoch 9/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0190 - acc: 0.9937 - val_loss: 0.0190 - val_acc: 0.9937
# Epoch 10/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0186 - acc: 0.9939 - val_loss: 0.0188 - val_acc: 0.9938
# Epoch 11/200
# 15022430/15022430 [==============================] - 19s 1us/step - loss: 0.0184 - acc: 0.9939 - val_loss: 0.0186 - val_acc: 0.9938
# Epoch 12/200
#  4540000/15022430 [========>.....................] - ETA: 13s - loss: 0.0182 - acc: 0.9940
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-1ba6fcf0e913> in <module>()
#      17 epochs = 200
#      18
# ---> 19 model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_validate, y_validate))
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# ~/.local/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1135     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1136       results = self._do_run(handle, final_targets, final_fetches,
# -> 1137                              feed_dict_tensor, options, run_metadata)
#    1138     else:
#    1139       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1353     if handle is None:
#    1354       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1355                            options, run_metadata)
#    1356     else:
#    1357       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1359   def _do_call(self, fn, *args):
#    1360     try:
# -> 1361       return fn(*args)
#    1362     except errors.OpError as e:
#    1363       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1338         else:
#    1339           return tf_session.TF_Run(session, options, feed_dict, fetch_list,
# -> 1340                                    target_list, status, run_metadata)
#    1341
#    1342     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
input_layer = Input(shape=(7, 1, 4))
conv_1 = Conv2D(filters=10, kernel_size=3, padding='same', activation='relu')(input_layer)
conv_2 = Conv2D(filters=10, kernel_size=3, padding='same', activation='relu')(conv_1)

flatten = Flatten()(conv_2)
predictions = Dense(4, activation='softmax')(flatten)

model = Model(input_layer, predictions)

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print(model.summary())

batch_size = 10000
epochs = 200

model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_validate, y_validate))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        (None, 7, 1, 4)           0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 7, 1, 10)          370
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 7, 1, 10)          910
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 70)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 4)                 284
# =================================================================
# Total params: 1,564
# Trainable params: 1,564
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 15022430 samples, validate on 1669159 samples
# Epoch 1/200
# 15022430/15022430 [==============================] - 19s 1us/step - loss: 0.1318 - acc: 0.9705 - val_loss: 0.0519 - val_acc: 0.9880
# Epoch 2/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0384 - acc: 0.9900 - val_loss: 0.0286 - val_acc: 0.9920
# Epoch 3/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0256 - acc: 0.9926 - val_loss: 0.0225 - val_acc: 0.9935
# Epoch 4/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0219 - acc: 0.9936 - val_loss: 0.0216 - val_acc: 0.9936
# Epoch 5/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0203 - acc: 0.9939 - val_loss: 0.0193 - val_acc: 0.9941
# Epoch 6/200
# 15022430/15022430 [==============================] - 19s 1us/step - loss: 0.0187 - acc: 0.9943 - val_loss: 0.0181 - val_acc: 0.9945
# Epoch 7/200
# 15022430/15022430 [==============================] - 18s 1us/step - loss: 0.0176 - acc: 0.9946 - val_loss: 0.0173 - val_acc: 0.9947
# Epoch 8/200
#  4810000/15022430 [========>.....................] - ETA: 12s - loss: 0.0173 - acc: 0.99
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-9ff8e0044149> in <module>()
#      17 epochs = 200
#      18
# ---> 19 model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(X_validate, y_validate))
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1239                         batch_logs[l] = o
#    1240
# -> 1241                     callbacks.on_batch_end(batch_index, batch_logs)
#    1242                     if callback_model.stop_training:
#    1243                         break
#
# ~/.local/lib/python3.5/site-packages/keras/callbacks.py in on_batch_end(self, batch, logs)
#     111         t_before_callbacks = time.time()
#     112         for callback in self.callbacks:
# --> 113             callback.on_batch_end(batch, logs)
#     114         self._delta_ts_batch_end.append(time.time() - t_before_callbacks)
#     115         delta_t_median = np.median(self._delta_ts_batch_end)
#
# ~/.local/lib/python3.5/site-packages/keras/callbacks.py in on_batch_end(self, batch, logs)
#     329         # will be handled by on_epoch_end.
#     330         if self.verbose and self.seen < self.target:
# --> 331             self.progbar.update(self.seen, self.log_values)
#     332
#     333     def on_epoch_end(self, epoch, logs=None):
#
# ~/.local/lib/python3.5/site-packages/keras/utils/generic_utils.py in update(self, current, values)
#     357             if self.target is not None:
#     358                 numdigits = int(np.floor(np.log10(self.target))) + 1
# --> 359                 barstr = '%%%dd/%d [' % (numdigits, self.target)
#     360                 bar = barstr % current
#     361                 prog = float(current) / self.target
#
# KeyboardInterrupt:
